# %%
import cv2
import os

# %% [markdown]
# ### READ IMAGE

# %%
image_path = os.path.join('data', 'images', 'jimin1.jpeg')

# %%
image_path
# Out:
# 'data\\images\\jimin1.jpeg'

# %%
image = cv2.imread(image_path)

# %%
image
# Out:
# array([[[  2,   2,   2],
#         [  2,   2,   2],
#         [  2,   2,   2],
#         ...,
#         [ 39,  43,  91],
#         [ 38,  42,  91],
#         [ 37,  41,  90]],
#
#        [[  2,   2,   2],
#         [  2,   2,   2],
#         [  2,   2,   2],
#         ...,
#         [ 40,  44,  92],
#         [ 40,  44,  93],
#         [ 39,  43,  92]],
#
#        [[  2,   2,   2],
#         [  2,   2,   2],
#         [  2,   2,   2],
#         ...,
#         [ 42,  46,  95],
#         [ 43,  46,  97],
#         [ 42,  45,  96]],
#
#        ...,
#
#        [[ 85,  74, 166],
#         [ 84,  73, 165],
#         [ 84,  73, 165],
#         ...,
#         [  0,   0,   0],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[ 87,  76, 169],
#         [ 86,  75, 167],
#         [ 85,  74, 167],
#         ...,
#         [  0,   0,   0],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[ 86,  74, 170],
#         [ 86,  75, 168],
#         [ 85,  73, 169],
# ...

# %%
image.shape
# Out:
# (549, 510, 3)

# %% [markdown]
# ## RENDER IMAGE

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(image)

# %% [markdown]
# ### Reorder colour channels

# %%
recolor = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(recolor)

# %% [markdown]
# pink = cv2.cvtColor(image, cv2.COLOR_BGR2LUV)

# %% [markdown]
# ### WRITE OUT IMAGE
